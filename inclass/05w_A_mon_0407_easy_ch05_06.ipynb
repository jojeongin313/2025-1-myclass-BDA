# %% [markdown]
# <a href="https://colab.research.google.com/github/jojeongin313/2025-1-myclass-BDA/blob/main/inclass/05w_A_mon_0407_easy_ch05_06.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##5주차

# %%
df2[['var1','var2']]
# Out:
#    var1  var2
# 0     4     2
# 1     3     6
# 2     6     1

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame({'var1':[4,3,6],'var2':[2,6,1]})
df
# Out:
#    var1  var2
# 0     4     2
# 1     3     6
# 2     6     1

# %%
df1=df.copy()
df1
# Out:
#    var1  var2
# 0     4     2
# 1     3     6
# 2     6     1

# %%
df1['var_sum'] = df1.var1+df1.var2
df1
# Out:
#    var1  var2  var_sum
# 0     4     2        6
# 1     3     6        9
# 2     6     1        7

# %%
df1['var_mean'] = (df1.var1+df1.var2)/2
df1
# Out:
#    var1  var2  var_sum  var_mean
# 0     4     2        6       3.0
# 1     3     6        9       4.5
# 2     6     1        7       3.5

# %%
df2=df.copy()
df2
# Out:
#    var1  var2
# 0     4     2
# 1     3     6
# 2     6     1

# %%
df2.sum()
# Out:
# var1    13
# var2     9
# dtype: int64

# %%
df2.sum(axis=0)
# Out:
# var1    13
# var2     9
# dtype: int64

# %%
df2.sum(axis=1)
# Out:
# 0    6
# 1    9
# 2    7
# dtype: int64

# %%
df2['mysum']=df2.sum(axis=1)
df2
# Out:
#    var1  var2  mysum
# 0     4     2     12
# 1     3     6     18
# 2     6     1     14

# %%
df2['mysum']=df2.sum(axis='columns')
df2
# Out:
#    var1  var2  mysum
# 0     4     2     18
# 1     3     6     27
# 2     6     1     21

# %%
df2[['var1','var2']]
# Out:
#    var1  var2
# 0     4     2
# 1     3     6
# 2     6     1

# %%
df2['var1']
# Out:
# 0    4
# 1    3
# 2    6
# Name: var1, dtype: int64

# %%
df2['mysum']=df2[['var1','var2']].mean(axis='columns')
df2
# Out:
#    var1  var2  mysum
# 0     4     2    3.0
# 1     3     6    4.5
# 2     6     1    3.5

# %% [markdown]
# ##mpg 데이터

# %%
# !git clone https://github.com/ai7dnn/data
# Out:
# Cloning into 'data'...
# remote: Enumerating objects: 24, done.
# remote: Counting objects: 100% (24/24), done.
# remote: Compressing objects: 100% (22/22), done.
# remote: Total 24 (delta 4), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (24/24), 2.14 MiB | 5.73 MiB/s, done.
# Resolving deltas: 100% (4/4), done.

# %%
mpg = pd.read_csv('data/mpg.csv')
mpg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   manufacturer  234 non-null    object
#  1   model         234 non-null    object
#  2   displ         234 non-null    float64
#  3   year          234 non-null    int64
#  4   cyl           234 non-null    int64
#  5   trans         234 non-null    object
#  6   drv           234 non-null    object
#  7   cty           234 non-null    int64
#  8   hwy           234 non-null    int64
#  9   fl            234 non-null    object
#  10  category      234 non-null    object
# dtypes: float64(1), int64(4), object(6)
# memory usage: 20.2+ KB

# %%
mpg.sample(3)
# Out:
#     manufacturer           model  displ  year  cyl       trans drv  cty  hwy  \
# 151       nissan  pathfinder 4wd    3.3  1999    6  manual(m5)   4   15   17
# 57         dodge     durango 4wd    3.9  1999    6    auto(l4)   4   13   17
# 24     chevrolet        corvette    5.7  1999    8    auto(l4)   r   15   23
#
#     fl category
# 151  r      suv
# 57   r      suv
# 24   p  2seater

# %%
mpg['total']=(mpg.cty + mpg.hwy) / 2
mpg.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl category  \
# 0         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 1         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 2         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 3         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 4         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact
#
#    total
# 0   23.5
# 1   25.0
# 2   25.5
# 3   25.5
# 4   21.0

# %%
mpg['mpg_mean']=mpg[['cty','hwy']].mean(axis=1)
mpg.sample(3)
# Out:
#     manufacturer              model  displ  year  cyl       trans drv  cty  \
# 171       subaru        impreza awd    2.5  2008    4  manual(m5)   4   19
# 54         dodge  dakota pickup 4wd    4.7  2008    8    auto(l5)   4    9
# 55         dodge  dakota pickup 4wd    5.2  1999    8  manual(m5)   4   11
#
#      hwy fl category  total  mpg_mean
# 171   25  p  compact   22.0      22.0
# 54    12  e   pickup   10.5      10.5
# 55    17  r   pickup   14.0      14.0

# %%
sum(mpg['total'])/len(mpg)
# Out:
# 20.14957264957265

# %%
mpg.total.mean()
# Out:
# np.float64(20.14957264957265)

# %%
mpg.shape
# Out:
# (234, 13)

# %%
len(mpg)
# Out:
# 234

# %%
sum(mpg['total'])/mpg.shape[0]
# Out:
# 20.14957264957265

# %%
mpg.total.describe()
# Out:
# count    234.000000
# mean      20.149573
# std        5.050290
# min       10.500000
# 25%       15.500000
# 50%       20.500000
# 75%       23.500000
# max       39.500000
# Name: total, dtype: float64

# %%
mpg.total.describe()['mean']
# Out:
# np.float64(20.14957264957265)

# %%
mpg.total.describe()[1]
# Out:
# <ipython-input-42-b4aef9eccf3a>:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   mpg.total.describe()[1]
# np.float64(20.14957264957265)

# %%
mpg.total.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
mpg.total.plot.hist(); #세미콜론이 <Axes: ylabel='Frequency'>텍스트를 없앰

# %%
# !pip install koreanize-matplotlib
# Out:
# Collecting koreanize-matplotlib
#   Downloading koreanize_matplotlib-0.1.1-py3-none-any.whl.metadata (992 bytes)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from koreanize-matplotlib) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->koreanize-matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->koreanize-matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->koreanize-matplotlib) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->koreanize-matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.11/dist-packages (from matplotlib->koreanize-matplotlib) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->koreanize-matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->koreanize-matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->koreanize-matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->koreanize-matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->koreanize-matplotlib) (1.17.0)
# Downloading koreanize_matplotlib-0.1.1-py3-none-any.whl (7.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 38.1 MB/s eta 0:00:00
# Installing collected packages: koreanize-matplotlib
# Successfully installed koreanize-matplotlib-0.1.1

# %%
import koreanize_matplotlib
# %config inlineBackend.figure_format = 'retina'

# %%
mpg.total.plot(kind='hist',title='히스토그램')
# Out:
# <Axes: title={'center': '히스토그램'}, ylabel='Frequency'>

# %%
import seaborn as sns
sns.histplot(mpg,x='total');

# %% [markdown]
# ##np.where()

# %%
np.where(mpg.total >= 20,'pass','fall')
# Out:
# array(['pass', 'pass', 'pass', 'pass', 'pass', 'pass', 'pass', 'pass',
#        'pass', 'pass', 'pass', 'pass', 'pass', 'pass', 'pass', 'fall',
#        'pass', 'fall', 'fall', 'fall', 'fall', 'fall', 'fall', 'pass',
#        'fall', 'pass', 'pass', 'fall', 'fall', 'fall', 'fall', 'fall',
#        'pass', 'pass', 'pass', 'pass', 'pass', 'pass', 'pass', 'fall',
#        'fall', 'pass', 'pass', 'fall', 'fall', 'fall', 'fall', 'fall',
#        'fall', 'fall', 'fall', 'fall', 'fall', 'fall', 'fall', 'fall',
#        'fall', 'fall', 'fall', 'fall', 'fall', 'fall', 'fall', 'fall',
#        'fall', 'fall', 'fall', 'fall', 'fall', 'fall', 'fall', 'fall',
#        'fall', 'fall', 'fall', 'fall', 'fall', 'fall', 'fall', 'fall',
#        'fall', 'fall', 'fall', 'fall', 'fall', 'fall', 'fall', 'fall',
#        'fall', 'fall', 'pass', 'pass', 'pass', 'pass', 'fall', 'fall',
#        'fall', 'fall', 'fall', 'pass', 'pass', 'pass', 'pass', 'pass',
#        'pass', 'pass', 'pass', 'pass', 'pass', 'pass', 'pass', 'pass',
#        'pass', 'pass', 'pass', 'pass', 'pass', 'pass', 'pass', 'pass',
#        'pass', 'pass', 'fall', 'fall', 'fall', 'fall', 'fall', 'fall',
#        'fall', 'fall', 'fall', 'fall', 'fall', 'fall', 'fall', 'fall',
#        'fall', 'fall', 'fall', 'fall', 'fall', 'pass', 'pass', 'pass',
#        'pass', 'pass', 'pass', 'pass', 'pass', 'pass', 'fall', 'fall',
#        'fall', 'fall', 'pass', 'pass', 'pass', 'pass', 'pass', 'pass',
#        'pass', 'pass', 'pass', 'pass', 'pass', 'pass', 'pass', 'pass',
#        'pass', 'pass', 'pass', 'pass', 'pass', 'fall', 'fall', 'fall',
#        'fall', 'fall', 'fall', 'pass', 'pass', 'pass', 'pass', 'pass',
#        'pass', 'pass', 'pass', 'pass', 'pass', 'pass', 'pass', 'pass',
#        'pass', 'pass', 'pass', 'pass', 'pass', 'pass', 'fall', 'fall',
#        'fall', 'fall', 'fall', 'fall', 'fall', 'fall', 'fall', 'pass',
#        'pass', 'pass', 'pass', 'pass', 'pass', 'pass', 'pass', 'pass',
#        'pass', 'pass', 'pass', 'fall', 'pass', 'pass', 'pass', 'pass',
#        'pass', 'pass', 'pass', 'pass', 'pass', 'pass', 'pass', 'pass',
#        'pass', 'pass'], dtype='<U4')

# %%
mpg['test'] = np.where(mpg.total >= 20, 'pass', 'fail')
mpg.sample(5)
# Out:
#     manufacturer          model  displ  year  cyl       trans drv  cty  hwy  \
# 114      hyundai         sonata    3.3  2008    6    auto(l5)   f   19   28
# 183       toyota          camry    3.0  1999    6    auto(l4)   f   18   26
# 136      lincoln  navigator 2wd    5.4  2008    8    auto(l6)   r   12   18
# 159       subaru   forester awd    2.5  1999    4  manual(m5)   4   18   25
# 43         dodge    caravan 2wd    3.3  2008    6    auto(l4)   f   11   17
#
#     fl category  total  mpg_mean  test
# 114  r  midsize   23.5      23.5  pass
# 183  r  midsize   22.0      22.0  pass
# 136  r      suv   15.0      15.0  fail
# 159  r      suv   21.5      21.5  pass
# 43   e  minivan   14.0      14.0  fail

# %%
import numpy as np

# 20 이상이면 pass, 그렇지 않으면 fail 부여
mpg['test'] = np.where(mpg['total'] >= 20, 'pass', 'fail')
mpg.sample(10)
# Out:
#     manufacturer                model  displ  year  cyl       trans drv  cty  \
# 89          ford      f150 pickup 4wd    5.4  2008    8    auto(l4)   4   13
# 12          audi           a4 quattro    2.8  1999    6  manual(m5)   4   17
# 76          ford       expedition 2wd    5.4  2008    8    auto(l6)   r   12
# 71         dodge  ram 1500 pickup 4wd    5.2  1999    8  manual(m5)   4   11
# 58         dodge          durango 4wd    4.7  2008    8    auto(l5)   4   13
# 177       toyota          4runner 4wd    4.0  2008    6    auto(l5)   4   16
# 159       subaru         forester awd    2.5  1999    4  manual(m5)   4   18
# 101        honda                civic    1.6  1999    4  manual(m5)   f   25
# 197       toyota              corolla    1.8  2008    4    auto(l4)   f   26
# 206       toyota    toyota tacoma 4wd    4.0  2008    6    auto(l5)   4   16
#
#      hwy fl    category  total  mpg_mean  test
# 89    17  r      pickup   15.0      15.0  fail
# 12    25  p     compact   21.0      21.0  pass
# 76    18  r         suv   15.0      15.0  fail
# 71    16  r      pickup   13.5      13.5  fail
# 58    17  r         suv   15.0      15.0  fail
# 177   20  r         suv   18.0      18.0  fail
# 159   25  r         suv   21.5      21.5  pass
# 101   32  r  subcompact   28.5      28.5  pass
# 197   35  r     compact   30.5      30.5  pass
# 206   20  r      pickup   18.0      18.0  fail

# %%
mpg['test'].value_counts()  # 연비 합격 빈도표 만들기
# Out:
# test
# pass    128
# fail    106
# Name: count, dtype: int64

# %%
mpg.test.value_counts()
# Out:
# test
# pass    128
# fail    106
# Name: count, dtype: int64

# %%
count_test = mpg['test'].value_counts()  # 연비 합격 빈도표를 변수에 할당
count_test
# Out:
# test
# pass    128
# fail    106
# Name: count, dtype: int64

# %%
type(mpg.test.value_counts())
# Out:
# pandas.core.series.Series

# %%
type(count_test)
# Out:
# pandas.core.series.Series

# %%
mpg.test.value_counts().plot.bar(rot=0);

# %%
sns.countplot(mpg, x='test', hue='test');

# %%
sns.countplot(mpg, x='test', hue='test', stat='percent');

# %%
sns.countplot(mpg, x="test", hue="test");

# %%
sns.countplot(mpg, x='test', hue='cyl', stat='percent');

# %%
sns.__version__
# Out:
# '0.13.2'

# %%
sns.countplot(mpg,x='test',hue='category',stat='percent')
# Out:
# <Axes: xlabel='test', ylabel='percent'>

# %%
np.where(mpg.total >= 30, 'A', np.where(mpg.total >= 20, 'B', 'C'))
# Out:
# array(['B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B',
#        'B', 'B', 'C', 'B', 'C', 'C', 'C', 'C', 'C', 'C', 'B', 'C', 'B',
#        'B', 'C', 'C', 'C', 'C', 'C', 'B', 'B', 'B', 'B', 'B', 'B', 'B',
#        'C', 'C', 'B', 'B', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C',
#        'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C',
#        'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C',
#        'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'B',
#        'B', 'B', 'B', 'C', 'C', 'C', 'C', 'C', 'A', 'B', 'B', 'B', 'B',
#        'A', 'A', 'A', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B',
#        'B', 'B', 'B', 'B', 'B', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C',
#        'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'B', 'B',
#        'B', 'B', 'B', 'B', 'B', 'B', 'B', 'C', 'C', 'C', 'C', 'B', 'B',
#        'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B',
#        'B', 'B', 'B', 'B', 'C', 'C', 'C', 'C', 'C', 'C', 'B', 'B', 'B',
#        'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B',
#        'A', 'A', 'A', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'B',
#        'B', 'B', 'B', 'B', 'A', 'B', 'B', 'B', 'B', 'B', 'B', 'C', 'B',
#        'A', 'A', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B'],
#       dtype='<U1')

# %%
mpg['grade'] = np.where(mpg.total >= 30, 'A', np.where(mpg.total >= 20, 'B', 'C'))
mpg.sample(5)
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 216   volkswagen   jetta    2.0  2008    4  manual(m6)   f   21   29  p
# 145       nissan  altima    3.5  2008    6  manual(m6)   f   19   27  p
# 146       nissan  altima    3.5  2008    6    auto(av)   f   19   26  p
# 35     chevrolet  malibu    3.5  2008    6    auto(l4)   f   18   29  r
# 33     chevrolet  malibu    2.4  2008    4    auto(l4)   f   22   30  r
#
#     category  total  mpg_mean  test grade
# 216  compact   25.0      25.0  pass     B
# 145  midsize   23.0      23.0  pass     B
# 146  midsize   22.5      22.5  pass     B
# 35   midsize   23.5      23.5  pass     B
# 33   midsize   26.0      26.0  pass     B

# %%
n_grade = mpg.grade.value_counts()
n_grade
# Out:
# grade
# B    118
# C    106
# A     10
# Name: count, dtype: int64

# %%
n_grade.plot.bar(rot=0);

# %%
n_grade = mpg.grade.value_counts().sort_index()
n_grade
# Out:
# grade
# A     10
# B    118
# C    106
# Name: count, dtype: int64

# %%
n_grade.plot.bar(rot=0);

# %%
sns.countplot(mpg, x='grade');

# %%
sns.countplot(mpg, x='grade', hue='grade');

# %%
sns.countplot(mpg, x='grade', hue='grade', stat='percent');

# %%
mpg.grade.value_counts().sort_index().index
# Out:
# Index(['A', 'B', 'C'], dtype='object', name='grade')

# %%
sns.countplot(mpg, x='grade', hue='grade', stat='percent', order=mpg.grade.value_counts().sort_index().index);

# %%
sns.countplot(mpg, x='grade', hue='grade', stat='percent', order=['A', 'B', 'C']);

# %%
mpg.grade.unique()
# Out:
# array(['B', 'C', 'A'], dtype=object)

# %%
np.sort(mpg.grade.unique())
# Out:
# array(['A', 'B', 'C'], dtype=object)

# %%
sns.countplot(mpg, x='grade', hue='grade', stat='percent', order=np.sort(mpg.grade.unique()));

# %%
s=mpg.grade
s= s.value_counts()
s=s.sort_index()
type(s)
# Out:
# pandas.core.series.Series

# %%
s=mpg.grade.value_counts().sort_index()
type(s)
# Out:
# pandas.core.series.Series

# %%
mpg['grade'] = np.where(mpg.total >= 30, 'A',
               np.where(mpg.total >= 25, 'B',
               np.where(mpg.total >= 20, 'C','D')))
mpg.sample(5)
# Out:
#     manufacturer              model  displ  year  cyl       trans drv  cty  \
# 217   volkswagen              jetta    2.5  2008    5    auto(s6)   f   21
# 203       toyota  toyota tacoma 4wd    3.4  1999    6  manual(m5)   4   15
# 78          ford       explorer 4wd    4.0  1999    6  manual(m5)   4   15
# 110      hyundai             sonata    2.4  2008    4    auto(l4)   f   21
# 108      hyundai             sonata    2.4  1999    4    auto(l4)   f   18
#
#      hwy fl category  total  mpg_mean  test grade
# 217   29  r  compact   25.0      25.0  pass     B
# 203   17  r   pickup   16.0      16.0  fail     D
# 78    19  r      suv   17.0      17.0  fail     D
# 110   30  r  midsize   25.5      25.5  pass     B
# 108   26  r  midsize   22.0      22.0  pass     C

# %% [markdown]
# ## 연산자 |(or) 메소드 isin

# %%
np.where((mpg.category == 'compact') |
         (mpg.category == 'subcompact') |
         (mpg.category == '2seater'), 'small', 'large')
# Out:
# array(['small', 'small', 'small', 'small', 'small', 'small', 'small',
#        'small', 'small', 'small', 'small', 'small', 'small', 'small',
#        'small', 'large', 'large', 'large', 'large', 'large', 'large',
#        'large', 'large', 'small', 'small', 'small', 'small', 'small',
#        'large', 'large', 'large', 'large', 'large', 'large', 'large',
#        'large', 'large', 'large', 'large', 'large', 'large', 'large',
#        'large', 'large', 'large', 'large', 'large', 'large', 'large',
#        'large', 'large', 'large', 'large', 'large', 'large', 'large',
#        'large', 'large', 'large', 'large', 'large', 'large', 'large',
#        'large', 'large', 'large', 'large', 'large', 'large', 'large',
#        'large', 'large', 'large', 'large', 'large', 'large', 'large',
#        'large', 'large', 'large', 'large', 'large', 'large', 'large',
#        'large', 'large', 'large', 'large', 'large', 'large', 'small',
#        'small', 'small', 'small', 'small', 'small', 'small', 'small',
#        'small', 'small', 'small', 'small', 'small', 'small', 'small',
#        'small', 'small', 'small', 'large', 'large', 'large', 'large',
#        'large', 'large', 'large', 'small', 'small', 'small', 'small',
#        'small', 'small', 'small', 'large', 'large', 'large', 'large',
#        'large', 'large', 'large', 'large', 'large', 'large', 'large',
#        'large', 'large', 'large', 'large', 'large', 'large', 'large',
#        'large', 'small', 'small', 'large', 'large', 'large', 'large',
#        'large', 'large', 'large', 'large', 'large', 'large', 'large',
#        'large', 'large', 'large', 'large', 'large', 'large', 'large',
#        'large', 'large', 'large', 'large', 'small', 'small', 'small',
#        'small', 'small', 'small', 'small', 'small', 'large', 'large',
#        'large', 'large', 'large', 'large', 'large', 'large', 'large',
#        'large', 'large', 'large', 'large', 'small', 'small', 'small',
#        'small', 'small', 'small', 'small', 'small', 'small', 'small',
#        'small', 'small', 'large', 'large', 'large', 'large', 'large',
#        'large', 'large', 'large', 'large', 'small', 'small', 'small',
#        'small', 'small', 'small', 'small', 'small', 'small', 'small',
#        'small', 'small', 'small', 'small', 'small', 'small', 'small',
#        'small', 'small', 'small', 'large', 'large', 'large', 'large',
#        'large', 'large', 'large'], dtype='<U5')

# %%
mpg['size'] = np.where((mpg.category == 'compact') |
                       (mpg.category == 'subcompact') |
                       (mpg.category == '2seater'), 'small', 'large')
mpg.sample(3)
# Out:
#     manufacturer       model  displ  year  cyl       trans drv  cty  hwy fl  \
# 185       toyota       camry    3.5  2008    6    auto(s6)   f   19   28  r
# 11          audi  a4 quattro    2.8  1999    6    auto(l5)   4   15   25  p
# 232   volkswagen      passat    2.8  1999    6  manual(m5)   f   18   26  p
#
#     category  total  mpg_mean  test grade   size
# 185  midsize   23.5      23.5  pass     C  large
# 11   compact   20.0      20.0  pass     C  small
# 232  midsize   22.0      22.0  pass     C  large

# %%
mpg['size'].value_counts()
# Out:
# size
# large    147
# small     87
# Name: count, dtype: int64

# %%
mpg['size'] = np.where(mpg.category.isin(['compact', 'subcompact', '2seater']), 'small', 'large')
mpg['size'].value_counts()
# Out:
# size
# large    147
# small     87
# Name: count, dtype: int64

# %%
mpg.shape[0] * mpg.shape[1]
# Out:
# 3042

# %%
mpg.shape
# Out:
# (234, 13)

# %%
mpg.size
# Out:
# 3042

# %% [markdown]
# ##정리하기

# %%
import pandas as pd
import numpy as np


mpg = pd.read_csv('data/mpg.csv')

mpg.shape
mpg.head()
mpg.tail()
mpg.info()
mpg.describe()


mpg = mpg.rename(columns = {'manufacturer' : 'company'})


mpg['total'] = (mpg['cty'] + mpg['hwy'])/2
mpg['test'] = np.where(mpg['total'] >= 20, 'pass', 'fail')

count_test = mpg['test'].value_counts()
count_test.plot.bar(rot = 0)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   manufacturer  234 non-null    object
#  1   model         234 non-null    object
#  2   displ         234 non-null    float64
#  3   year          234 non-null    int64
#  4   cyl           234 non-null    int64
#  5   trans         234 non-null    object
#  6   drv           234 non-null    object
#  7   cty           234 non-null    int64
#  8   hwy           234 non-null    int64
#  9   fl            234 non-null    object
#  10  category      234 non-null    object
# dtypes: float64(1), int64(4), object(6)
# memory usage: 20.2+ KB
# <Axes: xlabel='test'>

# %% [markdown]
# #단원 06

# %%
import pandas as pd

exam = pd.read_csv('data/exam.csv')
exam.sample(5)
# Out:
#     id  nclass  math  english  science
# 15  16       4    58       98       65
# 18  19       5    89       68       87
# 19  20       5    78       83       58
# 7    8       2    90       78       25
# 9   10       3    50       98       45

# %%
exam.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       20 non-null     int64
#  1   nclass   20 non-null     int64
#  2   math     20 non-null     int64
#  3   english  20 non-null     int64
#  4   science  20 non-null     int64
# dtypes: int64(5)
# memory usage: 932.0 bytes

# %%
exam.sample(frac=.2)
# Out:
#     id  nclass  math  english  science
# 4    5       2    25       80       65
# 3    4       1    30       98       58
# 16  17       5    65       68       98
# 10  11       3    65       65       65

# %%
exam.query('nclass ==1')
# Out:
#    id  nclass  math  english  science
# 0   1       1    50       98       50
# 1   2       1    60       97       60
# 2   3       1    45       86       78
# 3   4       1    30       98       58

# %%
exam.query('nclass == 2')
# Out:
#    id  nclass  math  english  science
# 4   5       2    25       80       65
# 5   6       2    50       89       98
# 6   7       2    80       90       45
# 7   8       2    90       78       25

# %%
exam.nclass ==2
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4      True
# 5      True
# 6      True
# 7      True
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# Name: nclass, dtype: bool

# %%
exam [exam.nclass ==2]
# Out:
#    id  nclass  math  english  science
# 4   5       2    25       80       65
# 5   6       2    50       89       98
# 6   7       2    80       90       45
# 7   8       2    90       78       25

# %%
exam.query('nclass == 2')
# Out:
#    id  nclass  math  english  science
# 4   5       2    25       80       65
# 5   6       2    50       89       98
# 6   7       2    80       90       45
# 7   8       2    90       78       25

# %%
exam.query('math > 50')
# Out:
#     id  nclass  math  english  science
# 1    2       1    60       97       60
# 6    7       2    80       90       45
# 7    8       2    90       78       25
# 10  11       3    65       65       65
# 14  15       4    75       56       78
# 15  16       4    58       98       65
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
exam.query('english >= 80')
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 4    5       2    25       80       65
# 5    6       2    50       89       98
# 6    7       2    80       90       45
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 11  12       3    45       85       32
# 12  13       4    46       98       65
# 13  14       4    48       87       12
# 15  16       4    58       98       65
# 19  20       5    78       83       58

# %%
# 1반이면서 수학 점수가 50 점 이상인 경우
exam.query('nclass == 1 & math >= 50')
# Out:
#    id  nclass  math  english  science
# 0   1       1    50       98       50
# 1   2       1    60       97       60

# %%
exam[(exam.nclass == 1) & (exam.math >= 50)] # 괄호를 반드시 사용
# Out:
#    id  nclass  math  english  science
# 0   1       1    50       98       50
# 1   2       1    60       97       60

# %%
exam.query('english < 90 | science < 50')
# Out:
#     id  nclass  math  english  science
# 2    3       1    45       86       78
# 4    5       2    25       80       65
# 5    6       2    50       89       98
# 6    7       2    80       90       45
# 7    8       2    90       78       25
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 13  14       4    48       87       12
# 14  15       4    75       56       78
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
exam.query('nclass == 1 | nclass == 3 | nclass == 5')
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
a = [1,3,5]
1 in a
# Out:
# True

# %%
4 in a
# Out:
# False

# %%
exam.query('nclass in [1, 3, 5]')
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
exam.query('nclass.isin([1, 3, 5])')
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
exam[exam.nclass.isin([1, 3, 5])]
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
nclass1 = exam.query('nclass == 1')
nclass1
# Out:
#    id  nclass  math  english  science
# 0   1       1    50       98       50
# 1   2       1    60       97       60
# 2   3       1    45       86       78
# 3   4       1    30       98       58

# %%
nclass2 = exam.query('nclass == 2')
nclass2
# Out:
#    id  nclass  math  english  science
# 4   5       2    25       80       65
# 5   6       2    50       89       98
# 6   7       2    80       90       45
# 7   8       2    90       78       25

# %%
nclass1.math.mean()
# Out:
# np.float64(46.25)

# %%
nclass2.english.mean()
# Out:
# np.float64(84.25)

# %%
df = pd.DataFrame({'sex'     : ['M', 'F', 'F', 'M'],
                   'country' : ['Korea', 'China', 'Japan', 'USA']})
df
# Out:
#   sex country
# 0   M   Korea
# 1   F   China
# 2   F   Japan
# 3   M     USA

# %%
df.query('sex == "M" & country == "Korea"')
# Out:
#   sex country
# 0   M   Korea

# %%
df.query("sex == 'M' & country == 'Korea'")
# Out:
#   sex country
# 0   M   Korea

# %%
var = 3
exam.query('nclass == @var')
# Out:
#     id  nclass  math  english  science
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32

# %%
var = 3
exam.query(f'nclass == {var}')
# Out:
#     id  nclass  math  english  science
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32

# %%
df.isin([0, 4])
# Out:
#         num_legs  num_wings
# falcon     False      False
# dog         True       True

# %%
df = pd.DataFrame({'num_legs': [2, 4], 'num_wings': [2, 0]},
                  index=['falcon', 'dog'])
df
# Out:
#         num_legs  num_wings
# falcon         2          2
# dog            4          0

# %%
df.isin([0, 4])
# Out:
#         num_legs  num_wings
# falcon     False      False
# dog         True       True

# %%
~df.isin([0, 4])
# Out:
#         num_legs  num_wings
# falcon      True       True
# dog        False      False

# %%
exam
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 4    5       2    25       80       65
# 5    6       2    50       89       98
# 6    7       2    80       90       45
# 7    8       2    90       78       25
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 12  13       4    46       98       65
# 13  14       4    48       87       12
# 14  15       4    75       56       78
# 15  16       4    58       98       65
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
exam.columns[2]
# Out:
# 'math'

# %%
exam[exam.columns[2]]
# Out:
# 0     50
# 1     60
# 2     45
# 3     30
# 4     25
# 5     50
# 6     80
# 7     90
# 8     20
# 9     50
# 10    65
# 11    45
# 12    46
# 13    48
# 14    75
# 15    58
# 16    65
# 17    80
# 18    89
# 19    78
# Name: math, dtype: int64

# %%
exam['math']
# Out:
# 0     50
# 1     60
# 2     45
# 3     30
# 4     25
# 5     50
# 6     80
# 7     90
# 8     20
# 9     50
# 10    65
# 11    45
# 12    46
# 13    48
# 14    75
# 15    58
# 16    65
# 17    80
# 18    89
# 19    78
# Name: math, dtype: int64

# %%
exam.math
# Out:
# 0     50
# 1     60
# 2     45
# 3     30
# 4     25
# 5     50
# 6     80
# 7     90
# 8     20
# 9     50
# 10    65
# 11    45
# 12    46
# 13    48
# 14    75
# 15    58
# 16    65
# 17    80
# 18    89
# 19    78
# Name: math, dtype: int64

# %%
exam.columns[1:4]
# Out:
# Index(['nclass', 'math', 'english'], dtype='object')

# %%
exam[['nclass', 'math', 'english']].head()
# Out:
#    nclass  math  english
# 0       1    50       98
# 1       1    60       97
# 2       1    45       86
# 3       1    30       98
# 4       2    25       80

# %%
exam
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 4    5       2    25       80       65
# 5    6       2    50       89       98
# 6    7       2    80       90       45
# 7    8       2    90       78       25
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 12  13       4    46       98       65
# 13  14       4    48       87       12
# 14  15       4    75       56       78
# 15  16       4    58       98       65
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %% [markdown]
# ## df.drop()

# %%
exam.drop(columns=['math', 'english'])
# Out:
#     id  nclass  science
# 0    1       1       50
# 1    2       1       60
# 2    3       1       78
# 3    4       1       58
# 4    5       2       65
# 5    6       2       98
# 6    7       2       45
# 7    8       2       25
# 8    9       3       15
# 9   10       3       45
# 10  11       3       65
# 11  12       3       32
# 12  13       4       65
# 13  14       4       12
# 14  15       4       78
# 15  16       4       65
# 16  17       5       98
# 17  18       5       90
# 18  19       5       87
# 19  20       5       58

# %%
exam
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 4    5       2    25       80       65
# 5    6       2    50       89       98
# 6    7       2    80       90       45
# 7    8       2    90       78       25
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 12  13       4    46       98       65
# 13  14       4    48       87       12
# 14  15       4    75       56       78
# 15  16       4    58       98       65
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
exam.drop(2)
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 3    4       1    30       98       58
# 4    5       2    25       80       65
# 5    6       2    50       89       98
# 6    7       2    80       90       45
# 7    8       2    90       78       25
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 12  13       4    46       98       65
# 13  14       4    48       87       12
# 14  15       4    75       56       78
# 15  16       4    58       98       65
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
exam.drop([2, 4, 6])
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 3    4       1    30       98       58
# 5    6       2    50       89       98
# 7    8       2    90       78       25
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 12  13       4    46       98       65
# 13  14       4    48       87       12
# 14  15       4    75       56       78
# 15  16       4    58       98       65
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
exam.drop(index=2)
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 3    4       1    30       98       58
# 4    5       2    25       80       65
# 5    6       2    50       89       98
# 6    7       2    80       90       45
# 7    8       2    90       78       25
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 12  13       4    46       98       65
# 13  14       4    48       87       12
# 14  15       4    75       56       78
# 15  16       4    58       98       65
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
exam.drop(index=[2, 4, 6])
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 3    4       1    30       98       58
# 5    6       2    50       89       98
# 7    8       2    90       78       25
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 12  13       4    46       98       65
# 13  14       4    48       87       12
# 14  15       4    75       56       78
# 15  16       4    58       98       65
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
exam.drop(labels=[2, 4, 6])
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 3    4       1    30       98       58
# 5    6       2    50       89       98
# 7    8       2    90       78       25
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 12  13       4    46       98       65
# 13  14       4    48       87       12
# 14  15       4    75       56       78
# 15  16       4    58       98       65
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
exam.drop(labels=[2, 4, 6],axis=0)
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 3    4       1    30       98       58
# 5    6       2    50       89       98
# 7    8       2    90       78       25
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 12  13       4    46       98       65
# 13  14       4    48       87       12
# 14  15       4    75       56       78
# 15  16       4    58       98       65
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
exam.query('nclass == 1')
# Out:
#    id  nclass  math  english  science
# 0   1       1    50       98       50
# 1   2       1    60       97       60
# 2   3       1    45       86       78
# 3   4       1    30       98       58

# %%
exam.query('nclass == 1')['math']
# Out:
# 0    50
# 1    60
# 2    45
# 3    30
# Name: math, dtype: int64

# %%
exam.query('nclass == 1').math
# Out:
# 0    50
# 1    60
# 2    45
# 3    30
# Name: math, dtype: int64

# %%
exam.query('nclass == 1')[['math']]
# Out:
#    math
# 0    50
# 1    60
# 2    45
# 3    30

# %%
exam.query('nclass == 1')['math'].to_frame()
# Out:
#    math
# 0    50
# 1    60
# 2    45
# 3    30

# %%
exam.query('nclass == 1')[['math', 'science']]
# Out:
#    math  science
# 0    50       50
# 1    60       60
# 2    45       78
# 3    30       58

# %%
exam.query('math >= 50')[['id', 'math']]
# Out:
#     id  math
# 0    1    50
# 1    2    60
# 5    6    50
# 6    7    80
# 7    8    90
# 9   10    50
# 10  11    65
# 14  15    75
# 15  16    58
# 16  17    65
# 17  18    80
# 18  19    89
# 19  20    78

# %%
exam[exam.math >= 50][['id', 'math']].head()
# Out:
#    id  math
# 0   1    50
# 1   2    60
# 5   6    50
# 6   7    80
# 7   8    90

# %%
exam[exam.math >= 50] \
    [['id', 'math']] \
    .head()
# Out:
#    id  math
# 0   1    50
# 1   2    60
# 5   6    50
# 6   7    80
# 7   8    90

# %% [markdown]
# ##정렬

# %%
exam.sort_values('math')
# Out:
#     id  nclass  math  english  science
# 8    9       3    20       98       15
# 4    5       2    25       80       65
# 3    4       1    30       98       58
# 2    3       1    45       86       78
# 11  12       3    45       85       32
# 12  13       4    46       98       65
# 13  14       4    48       87       12
# 0    1       1    50       98       50
# 9   10       3    50       98       45
# 5    6       2    50       89       98
# 15  16       4    58       98       65
# 1    2       1    60       97       60
# 10  11       3    65       65       65
# 16  17       5    65       68       98
# 14  15       4    75       56       78
# 19  20       5    78       83       58
# 17  18       5    80       78       90
# 6    7       2    80       90       45
# 18  19       5    89       68       87
# 7    8       2    90       78       25

# %%
exam.sort_values('math', ascending=False).head(7)
# Out:
#     id  nclass  math  english  science
# 7    8       2    90       78       25
# 18  19       5    89       68       87
# 6    7       2    80       90       45
# 17  18       5    80       78       90
# 19  20       5    78       83       58
# 14  15       4    75       56       78
# 10  11       3    65       65       65

# %%
exam.sort_values(['nclass', 'math'], ascending=False).head(5)
# Out:
#     id  nclass  math  english  science
# 18  19       5    89       68       87
# 17  18       5    80       78       90
# 19  20       5    78       83       58
# 16  17       5    65       68       98
# 14  15       4    75       56       78

# %%
exam.sort_values(['nclass', 'math'], ascending=[True, False]).head(10)
# Out:
#     id  nclass  math  english  science
# 1    2       1    60       97       60
# 0    1       1    50       98       50
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 7    8       2    90       78       25
# 6    7       2    80       90       45
# 5    6       2    50       89       98
# 4    5       2    25       80       65
# 10  11       3    65       65       65
# 9   10       3    50       98       45

# %%
exam.sort_values(by=['nclass', 'math'], ascending=[True, False]).head(10)
# Out:
#     id  nclass  math  english  science
# 1    2       1    60       97       60
# 0    1       1    50       98       50
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 7    8       2    90       78       25
# 6    7       2    80       90       45
# 5    6       2    50       89       98
# 4    5       2    25       80       65
# 10  11       3    65       65       65
# 9   10       3    50       98       45

# %%
exam.sort_index()
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 4    5       2    25       80       65
# 5    6       2    50       89       98
# 6    7       2    80       90       45
# 7    8       2    90       78       25
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 12  13       4    46       98       65
# 13  14       4    48       87       12
# 14  15       4    75       56       78
# 15  16       4    58       98       65
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
exam.sort_index(ascending=False)
# Out:
#     id  nclass  math  english  science
# 19  20       5    78       83       58
# 18  19       5    89       68       87
# 17  18       5    80       78       90
# 16  17       5    65       68       98
# 15  16       4    58       98       65
# 14  15       4    75       56       78
# 13  14       4    48       87       12
# 12  13       4    46       98       65
# 11  12       3    45       85       32
# 10  11       3    65       65       65
# 9   10       3    50       98       45
# 8    9       3    20       98       15
# 7    8       2    90       78       25
# 6    7       2    80       90       45
# 5    6       2    50       89       98
# 4    5       2    25       80       65
# 3    4       1    30       98       58
# 2    3       1    45       86       78
# 1    2       1    60       97       60
# 0    1       1    50       98       50

# %%
exam.sort_index(axis=1,ascending=False)
# Out:
#     science  nclass  math  id  english
# 0        50       1    50   1       98
# 1        60       1    60   2       97
# 2        78       1    45   3       86
# 3        58       1    30   4       98
# 4        65       2    25   5       80
# 5        98       2    50   6       89
# 6        45       2    80   7       90
# 7        25       2    90   8       78
# 8        15       3    20   9       98
# 9        45       3    50  10       98
# 10       65       3    65  11       65
# 11       32       3    45  12       85
# 12       65       4    46  13       98
# 13       12       4    48  14       87
# 14       78       4    75  15       56
# 15       65       4    58  16       98
# 16       98       5    65  17       68
# 17       90       5    80  18       78
# 18       87       5    89  19       68
# 19       58       5    78  20       83

# %%
exam.sort_index(axis=1).head(3)
# Out:
#    english  id  math  nclass  science
# 0       98   1    50       1       50
# 1       97   2    60       1       60
# 2       86   3    45       1       78

# %%
exam.sort_index(axis=1,ascending=False).head(3)
# Out:
#    science  nclass  math  id  english
# 0       50       1    50   1       98
# 1       60       1    60   2       97
# 2       78       1    45   3       86

# %% [markdown]
# #종료
